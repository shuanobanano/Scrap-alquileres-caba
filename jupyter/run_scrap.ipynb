# %% [markdown]
# I need to rename the output. Now we are talking of 'departamentos', i could do the same with "locales-comerciales"
#
# Should add the new url, and prepare for a new analysis for both components.

# %%
import pandas as pd
from config.config_jupyter import set_wd
set_wd()
from src.zonaprop import main_scrap_zonaprop
# Out:
# c:\Users\marti\OneDrive\Documentos\Trabajos Indec\Scrap alquileres caba\jupyter

# %%
scrap = main_scrap_zonaprop(type_building="locales-comerciales",export_final_results=True)

# %%
# pd.DataFrame(scrap).to_parquet("output/zonaprop_locales-comerciales.pkt")

# %%
# pd.read_parquet("output/zonaprop_vivienda.pkt")
# Out:
#             Price                               Location  \
# 0         USD 900              Belgrano, Capital Federal
# 1       $ 450.000               Almagro, Capital Federal
# 2       $ 500.000          Barrio Norte, Capital Federal
# 3     $ 2.000.000              Belgrano, Capital Federal
# 4       $ 550.000                   Las Cañitas, Palermo
# ...           ...                                    ...
# 9390      USD 550              Recoleta, Capital Federal
# 9391    $ 250.000            Colegiales, Capital Federal
# 9392    $ 700.000              Recoleta, Capital Federal
# 9393    $ 250.000             Caballito, Capital Federal
# 9394    $ 210.000  Centro / Microcentro, Capital Federal
#
#                                     Address  Has_photo  \
# 0                         O'higgins al 2200       True
# 1     Tte. Gral. Juan Domingo Perón al 4300       True
# 2                         AV. SANTA FE 2100       True
# ...

# %%
# import os
# %notebook test.ipynb
# os.system('shutdown /s /t 1')

# %%
from config.config_jupyter import set_wd
set_wd()
# Out:
# c:\Users\marti\OneDrive\Documentos\Trabajos Indec\Scrap alquileres caba

# %%
import pandas as pd
import numpy as np
from botasaurus import *
import time
import requests
from typing import Literal
from src.constants import zona_prop_url


def _parse_property_listings(soup) -> list:
    """Parses property listings from a BeautifulSoup object.

    Args:
        soup (BeautifulSoup): A BeautifulSoup object containing the HTML content.

    Returns:
        list: A list of dictionaries, each representing a property listing.
    """
    property_elements = soup.select('div.sc-1tt2vbg-4.dFNvko')
    # print(property_elements)
    properties = []
    for property_element in property_elements:
        print(property_element)
        try:
            properties.append(_parse_property(property_element))
        except Exception:
            #There are 'Developing' buildings with a range of prices. 
            pass
    return properties

def _parse_property(property_element) -> dict:
    """Parses an individual property from the property element.

    Args:
        property_element (Tag): A BeautifulSoup Tag representing a property element.

    Returns:
        dict: A dictionary containing property details.
    """
    price_element = property_element.select_one('div[data-qa="POSTING_CARD_PRICE"]')
    location_element = property_element.select_one('div[data-qa="POSTING_CARD_LOCATION"]')
    address_element = property_element.select_one('div[class="sc-ge2uzh-0 eXwAuU"]') 
    photo_elements = property_element.select('img')
    has_photo = any(photo.get('src').endswith('isFirstImage=true') for photo in photo_elements) #Does not work because of "lazy" js
    features_elements = property_element.select('div[data-qa="POSTING_CARD_FEATURES"] span')
    summarize_element = property_element.select_one('a.sc-i1odl-12.EWzaP')
    description_element = property_element.select_one('div[data-qa="POSTING_CARD_DESCRIPTION"]')
    expensas_element = property_element.select_one('div[data-qa="expensas"]')
    ap_link_element = property_element.select_one('div[data-qa="posting PROPERTY"]')['data-to-posting']
    # print(property_element)

    dict_with_info = {
        'Price': price_element.text if price_element else np.nan,
        'Location': location_element.text if location_element else np.nan,
        'Address': address_element.text if address_element else np.nan,
        'Has_photo': has_photo,
        'Features': [feature_element.text for feature_element in features_elements],
        'Summarize': summarize_element.text if summarize_element else np.nan,
        'Description': description_element.text if description_element else np.nan,
        'Expensas': expensas_element.text if expensas_element else np.nan,
        'Link': zona_prop_url + ap_link_element if ap_link_element else np.nan,
    }
    
    # print(dict_with_info)
    
    return dict_with_info
    
    
def scrape_property_listings(request: AntiDetectRequests, link: str) -> list:
    """Scrapes property listings from ZonaProp.

    Args:
        request (AntiDetectRequests): An instance of AntiDetectRequests.
        link (str): The URL of the property listings page.

    Returns:
        list: A list of dictionaries, each representing a property listing.
    """
    properties = []
    itereation_count = 0#!
    while True:
        itereation_count += 1#!
        try:
            soup = request.bs4(link)
            # print(soup)
            properties += _parse_property_listings(soup)
            # Find the next page button
            next_page = soup.select_one('a[data-qa="PAGING_NEXT"]')
            if itereation_count >= 1:#!
                break#!
            if next_page and next_page['href']:
                # Update the link for the next iteration
                link = zona_prop_url + next_page['href']
                print(next_page['href'])
            else:
                # No more pages, break the loop
                break
        except requests.exceptions.HTTPError as e:
            print(f"HTTPError occurred: {e}. Retrying in 15 minutes.")
            time.sleep(15*60) # Sleep for 15 minutes
        except Exception as e:
            print(f"An unknown error occurred: {e}.")
            break
    return properties

def _export_scrap_zonaprop(scrap_results:dict,
                           type_operation:str,
                           type_building:str):
    pd.DataFrame(scrap_results).to_parquet(f"./output/zonaprop_{type_operation}_{type_building}.pkt")

def main_scrap_zonaprop(
    type_operation: Literal["alquiler", "venta"] = "alquiler", #bug with "venta"
    type_building:Literal["locales-comerciales", "departamentos","oficinas-comerciales"] = "departamentos",
    export_final_results:bool = True,
                        ) -> list | None:
    """Runs the main process of scraping property listings from ZonaProp.

    Returns:
        list: A list of dictionaries, each representing a property listing.
    """
    try:
        request = AntiDetectRequests()
        url = zona_prop_url + type_building + f"-{type_operation}-capital-federal.html"
        final_dict = scrape_property_listings(request, url)
        # print(final_dict)
        if export_final_results:
            _export_scrap_zonaprop(final_dict, type_operation ,type_building)
            print("Results exported correctly")
        return final_dict
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
test = main_scrap_zonaprop(type_operation="venta", export_final_results=False)
# Out:
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="53023143" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-departamento-belgrano-53023143.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><img alt="Departamento · 52m² · 3 Ambientes" fetchpriority="high" height="100%" loading="eager" src="https://imgar.zonapropcdn.com/avisos/1/00/53/02/31/43/360x266/1897142528.jpg?isFirstImage=true" style="object-fit:cover" width="100%"/></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 114.900</div></div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Franklin Roosvelt al 3000</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Belgrano, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->52 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->52 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->3 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 baño<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-departamento-belgrano-53023143.html">Departamento - Belgrano</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">¡Impecable 3 ambientes en Colegiales! Ingresamos a un cómodo y muy luminoso living comedor con salida al balcón a pulmón de manzana con gran vista abierta. Su cocina se encuentra recientemente reciclada y también con ventana al exterior lo que le otorga luz y ventilación, Dos cómodos dormitorios con placar de piso a techo hacia al pulmón de manzana comparten un baño remodelado y también con ventilación natural por de parquet impecables y plastificados. Calefacción por aire, con pico de conexión para un tiro balanceado. Apto Profesional. </div></div><div><span class="sc-ryls1p-0 bzIPYI" color="#7C98A7" label="Super destacado">Super destacado</span></div></div><div class="sc-i1odl-4 kkjIdG"><div class="sc-hlm4rl-3 jyNRdv"><div class="sc-hlm4rl-0 iatNmF"><div class="sc-hlm4rl-1 iodvHu"></div><img alt="logo publisher" class="sc-hlm4rl-2 kaufJn" data-qa="POSTING_CARD_PUBLISHER" loading="lazy" src="https://imgar.zonapropcdn.com/empresas/1/00/30/01/10/10/130x70/logo_basso-bienes-raices_7.jpg"/></div></div><div class="sc-i1odl-8 jTSHuu"><div class="sc-pr9m2p-1 fajRf"><div class="sc-pr9m2p-2 idaYLz"><button aria-label="Favorito" class="sc-1b3blmr-0 blZEzl" data-qa="CARD_FAV" font-size="16px" font-weight="500"><svg color="currentColor" fill="currentColor" font-size="25px" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 16 14" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M8 13.7c-.1 0-.3 0-.4-.1l-5.8-6a4.05 4.05 0 010-5.9C3.4.1 6.1.1 7.7 1.7l.3.4.4-.4c1.6-1.6 4.3-1.6 5.9 0  ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="53027577" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-bau-propiedades:-impecable-4-ambientes-de-categoria-2-53027577.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><img alt="Departamento · 126m² · 4 Ambientes · 2 Cocheras" fetchpriority="high" height="100%" loading="eager" src="https://imgar.zonapropcdn.com/avisos/1/00/53/02/75/77/360x266/1897241096.jpg?isFirstImage=true" style="object-fit:cover" width="100%"/></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 750.000</div></div><div class="sc-12dh9kl-2 kzrlNE" data-qa="expensas">$ 290.000 Expensas</div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Sucre al 800</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Belgrano, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->146 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->126 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->4 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->3 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->3 baños<!-- --> </span></span><span><img class="sc-1uhtbxc-1 eykaou" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 coch.<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-bau-propiedades:-impecable-4-ambientes-de-categoria-2-53027577.html">Bau Propiedades: Impecable 4 Ambientes de Categoría, 2 Cocheras, Amenities, Bajo Begrano!</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Venta- 4 ambientes- dependencia- 2 cocheras- baulera- seg. 24hs- amenities- bajo belgranoimpecable propiedad ubicada en un edificio de gran categoría en Bajo Belgrano. El edificio de líneas arquitectónicas muy modernas cuenta con jardines verticales, materiales nobles y eximio diseño y calidad constructiva. Palier semiprivado. Gran recepción compuesta por living y comedor formal. Toilette de visitas. Al frente un gran balcón corrido aterrazado, con sector para living de exterior. El área ínitima cuenta con un dormitorio principal en suite con vestidor y placard a medida. Cuenta además con otros dos dormitorios con placards ambos súper luminosos. Segundo baño completo. Área de servicio con cocina con barra desayunadora, mesada de silestone, anafe a gas, campana extractora y horno empotrado. Lavadero independiente, dependencia con su baño y acceso de servicio. 2 cocheras fijas cubiertas y baulera. Información adicional: doble vidriado hermético en toda la unidad, pisos entablonados de bambú, revestimiento en hall distribuidor de cemento alisado, aire acondicionado invididual, calefacción por losa radiante con termostato ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="52987858" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-departamento-en-venta-3-ambientes-villa-crespo-52987858.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><img alt="Departamento · 55m² · 2 Ambientes" fetchpriority="high" height="100%" loading="eager" src="https://imgar.zonapropcdn.com/avisos/1/00/52/98/78/58/360x266/1896374682.jpg?isFirstImage=true" style="object-fit:cover" width="100%"/></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 158.900</div></div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Av Córdoba al 4300 Piso 8°</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Palermo Viejo, Palermo</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->55 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 baño<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-departamento-en-venta-3-ambientes-villa-crespo-52987858.html">Departamento en Venta 3 Ambientes, Villa Crespo</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Asesor: maibelyn roa Ver datosventa de departamento 2 ambientes palermo/villa crespo en construcción-55, 37mts totalesEl desarrollo cuenta con 2 torres, la propiedad publicada se ubica en la torre 1, piso 8 al jardínDentro del emprendimiento encontramos 15 niveles y dos subsuelos con cocheras. Las unidades cuentan-anafe eléctrico de 4 hornallas-horno eléctrico empotrado-Mueble bajo mesada y Mesada-Bacha de acero inoxidable-Grifería: Monocomando. -Baños principales con bañeras. los amenities-Gimnasio-salón de usos múltiples. Kids club &amp;amp; Playground. -Laundry. -Pileta con solárium interior y exterior. Ducha finlandesaCon excelente ubicación a 2 cuadras de Av. Scalabrini Ortiz. Cercano a hospitales, universidades, colegios, locales gastronómicos y de indumentaria. posibilidad de blanqueo O financiaciónconsultar por unidades de 1, 2 o 3 ambientes disponibles y Cocherasentrega: dic 2023valor de venta: U$S 158. 900. Los metros publicados son aproximados, las medidas exactas surgirán de la escritura traslativa de dominio. La venta de este inmueble está sujeta a la tramitación del Código de Transferencia de Inmuebles (coti), de conformidad con la normativa vigente (Res. Afip 2371/08, 2439/08 y ccs. ) por parte del propietario. En cumplimiento de las leyes provinciales vigentes que regulan elcorretaje inmobiliario, Ley Nacional 25. 028, Ley 22. 802 de Lealtad Comercial, Ley 24. 240 de Defensa al Consumidor, las normas del Código Civil y Comercial de la Nación y Constitucionales, los asesores no ejercen el corretaje inmobiliario. Codigoinmatricula Cucicba 4263</div></div><div><span class ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 kWwuJH" data-id="51677035" data-posting-type="DEVELOPMENT" data-qa="posting DEVELOPMENT" data-to-posting="/propiedades/emprendimiento/ememvein-haaus-ii-studios-2-y-3-ambientes!-51677035.html"><div class="sc-i1odl-1 krobxD"><div class="sc-i1odl-32 eyOlpw"><div class="sc-n2cjqs-0 harMYs" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><span class="sc-1j3twev-0 hnXuJe"><span class="sc-ryls1p-0 sc-bwrqy4-0 gTPIFa faXpQU">En Pozo</span></span><span class="sc-1j3twev-0 eIDtiR"></span><span class="sc-1j3twev-0 gqVVqp"><div class="sc-hlm4rl-3 jyNRdv"><div class="sc-hlm4rl-0 kxKGSi"><div class="sc-hlm4rl-1 iodvHu"></div><img alt="logo publisher" class="sc-hlm4rl-2 djpVeL" data-qa="POSTING_CARD_PUBLISHER" loading="lazy" src="https://imgar.zonapropcdn.com/empresas/1/00/30/46/89/83/130x70/logo_cek-group_1654738012212.jpg"/></div></div></span></div></div><div class="sc-i1odl-2 gMrXuN"><div class="sc-ryls1p-4 jalEBE">Exclusive</div><div class="sc-i1odl-3 kHALbX" style="justify-content:start;padding:0px;overflow:unset"><h2 class="sc-i1odl-5 kodFeO" style="display:block"><a class="sc-i1odl-30 cVmiMy" href="/propiedades/emprendimiento/ememvein-haaus-ii-studios-2-y-3-ambientes!-51677035.html">Haaus II - Studios, 2 y 3 Ambientes!</a></h2><div class="sc-i1odl-6 eirRkt" style="margin:8px 0"><h5 class="sc-i1odl-11 jTsLEC"><a class="sc-i1odl-12 EWzaP" data-qa="POSTING_CARD_LOCATION" href="/propiedades/emprendimiento/ememvein-haaus-ii-studios-2-y-3-ambientes!-51677035.html" style="font-size:14px">Armenia 1209 Palermo Soho, Palermo</a></h5></div><div class="sc-i1odl-6 kgNoEe" style="margin:2px 0px 0px;white-space:normal"><div class="sc-i1odl-31 gVYSUG"><div class="price-container"><div class="label">Desde</div><div class="price" data-qa="POSTING_CARD_PRICE_FROM">USD 83.000</div></div><div class="price-container"><div class="label">Hasta</div><div class="price" data-qa="POSTING_CARD_PRICE_TO">USD 361.000</div></div></div></div><div class="sc-i1odl-7 bJBsWF"></div><div class="sc-i1odl-6 eirRkt" style="margin:8px 0;max-height:22px"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 dqGghR" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->33 un.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 a 3 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->24 a 74 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 gVoQmK" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->31 a 120 m²<!-- --> </span></span></div></div><div class="sc-i1odl-6 eirRkt" style="align-content:start;flex-direction:row;flex-wrap:wrap;margin:8px 0;overflow:hidden"><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Gimnasio</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Parrilla</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Solarium</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Pileta</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Balcón</span></div></div><div class="sc-i1odl-6 eirRkt"></div><div class="sc-i1odl-7 bJBsWF" style="width:100%"></div><div class="sc-i1odl-4 kkjIdG"  ...
# Clase no funciona
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="53028204" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-torre-quantum-bellini-libertador-nunez-belgrano-53028204.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 1.550.000</div></div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Av. Libertador al 7400 (esq. Núñez) Piso Altísimo! Quantum Bellini</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Núñez, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->225 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->225 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->4 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->3 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->5 baños<!-- --> </span></span><span><img class="sc-1uhtbxc-1 eykaou" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 coch.<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-torre-quantum-bellini-libertador-nunez-belgrano-53028204.html">Torre Quantum Bellini Libertador · Nuñez · Belgrano · Piso Altísimo Vista Rio · 225 m2</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Quantum Bellini: El mejor proyecto de la zona! 2 Torres de categoría con todos los amenities y servicios de lujo! Posesión: Junio 2024 aprox. Este 4 ambientes con dependencia en un piso muy alto tiene la siguiente superficie: 2 cocheras fijas y 1 baulera (No incluidas en el precio publicado) Cubierta 182m²Semi cubierta 27m²Amenities 17m²Superficie total 225m²Cuenta con living comedor apaisado con salida a balcón aterrazado con excelente vista al río, 3 dormitorios en suite, 3 baños completos más toilette de recepción, cocina completa con comedor diario, dependencia de servicio con su baño, doble circulación, 2 cocheras fijas y 1 baulera (No incluidas en el precio publicado, su valor es de u$s 150. 000. -) Amenities: Piscina cubiertaPiscina descubierta climatizadaGimnasioPiscina de niñosSalon de fiestas / sumparrillasKids ClubBusiness Centerspacavas / Habanos RoomResto BarCocina GourmetServicios: SeguridadConciergeLaundryCarwashIntendenciaCocheras de cortesíafilippo propiedades </div></div><div><span class="sc-ryls1p-0 bzIPYI" color="#7C98A7" label="Super destacado">Super destacado</span></div></div><div class="sc-i1odl-4 kkjIdG"><div class="sc-hlm4rl-3 jyNRdv"><div class="sc-hlm4rl-0 iatNmF"><div class="sc-hlm4rl-1 iodvHu"></div><img alt="logo publisher" class="sc-hlm4rl-2 kaufJn" data-qa="POSTING_CARD_PUBLISHER" loading="lazy" src="https://imgar.zonapropcdn.co ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="53022882" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-barrancas-de-belgrano-la-pampa-1900-piso-6-53022882.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"><span class="sc-14rw2v7-1 hVTDoz"><img class="sc-14rw2v7-2 fwUYlt" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/tagsSprite.png"/></span><span class="sc-14rw2v7-1 hVTDoz"><img class="sc-14rw2v7-2 dVQpDM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/tagsSprite.png"/></span></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 499.000</div></div><div class="sc-12dh9kl-2 kzrlNE" data-qa="expensas">$ 81.000 Expensas</div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">La Pampa 1900</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Belgrano, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->233 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->183 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->6 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->4 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 baños<!-- --> </span></span><span><img class="sc-1uhtbxc-1 eykaou" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 coch.<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-barrancas-de-belgrano-la-pampa-1900-piso-6-53022882.html">Barrancas de Belgrano • La Pampa 1900 • Piso • 6 Ambientes • Patio • Cochera</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Piso de seis ambientes distribuido en planta amplia, confortable y luminosa, con salida a patio. Hall, toilette y living comedor. Cocina con comedor diario y dependencia de servicio. Cuatro dormitorios (Ppal. En suite con vestidor) baño completo y salida a balcón corrido. Cochera fija, cubierta. Amenities: Terraza y sector parrilla. El edificio está ubicado a tres cuadras de Av. Juramento y a cuatro cuadras de Av. Del Libertador, en pleno Barrancas de Belgrano. En una zona de calles arboladas, con variedad de medios de transporte y ágiles conexiones a toda la ciudad de Buenos Aires. David Cipolla PropiedadesMatrículas 4052-cucicba I 6065-cmcpsi</div></div><div><span class="sc-ryls1p-0 bzIPYI" color="#7C98A7" label="Super destacado">Super destacado</span></div></div><div class="sc-i1odl-4 kkjIdG"><div class="sc-hlm4rl-3 jyNRdv"><div class="sc-hlm4rl-0 iatNmF"><div class="sc-hlm4rl-1 iodvHu"></div><img alt="logo publisher" class="sc-hlm4rl-2 kaufJn" data-qa="POSTING_CARD_PUBLISHER" loading="lazy" src="https://imgar.zonapropcdn.com/empresas/1/00/17/07/67/ ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="52737178" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-venta-a-estrenar-departamento-2-ambientes-con-parrilla-52737178.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"><span class="sc-14rw2v7-1 hVTDoz"><img class="sc-14rw2v7-2 dVQpDM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/tagsSprite.png"/></span></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 133.000</div></div><div class="sc-12dh9kl-2 kzrlNE" data-qa="expensas">$ 20.000 Expensas</div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Planes al 1100</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Caballito, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->60 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->49 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 baño<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-venta-a-estrenar-departamento-2-ambientes-con-parrilla-52737178.html">Venta a Estrenar Departamento 2 Ambientes con Parrilla Propia en Caballito</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Unico 2 ambientes con parrilla propia, piscina. Cochera opcional. Luz Y ubicación. La propiedad es a estrenar, se encuentra dentro de un emprendimiento de 13 modernas unidades de excelente calidad con pileta todo sol y cocheras opcionales. descripción: - Amplio balcón aterrazado con parrilla propia. Vista hacia la pileta. - Living comedor con piso flotante simil madera. - Cocina cómoda con gran espacio de guardado y lugar para lavarropas. - Habitación con gran placard con interiores y ventanal. Piso flotante simil madera. - Baño completo con excelentes terminaciones, artefactos y griferías de primera línea. detalles: - Calefacción estufa aire balanceado- Agua caliente por calefón. - Cocina con mesada de Silestone y gran espacio de guardado. - Pre-instalación de Aire Acondicionado. - Persianas en todos los ambientes. - El edificio cuenta con espacios únicos, mucha ventilación y una piscina con mucho sol. - Amplio Ascensor automático con dos puertas: De última generación en acero inoxidableimportante el emprendimiento cuenta con cocheras disponibles opcionales (venta por separado). ubicación: - Ubicado en pleno barrio de Caballito, pero dentro de una zona muy tranquila y rodeada de verde. Acceso directo a zona comercial, restaurantes, renombrados colegios. - A 3 cuadras del monumento del cid Campeador. - A pocas cuadras de Plaza Irlanda y de Parque Cent ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 kWwuJH" data-id="45007144" data-posting-type="DEVELOPMENT" data-qa="posting DEVELOPMENT" data-to-posting="/propiedades/emprendimiento/ememvein-canvas-barracas-45007144.html"><div class="sc-i1odl-1 krobxD"><div class="sc-i1odl-32 eyOlpw"><div class="sc-n2cjqs-0 harMYs" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><span class="sc-1j3twev-0 hnXuJe"><span class="sc-ryls1p-0 sc-bwrqy4-0 gTPIFa hZUqIS">En Construcción</span></span><span class="sc-1j3twev-0 eIDtiR"></span><span class="sc-1j3twev-0 gqVVqp"><div class="sc-hlm4rl-3 jyNRdv"><div class="sc-hlm4rl-0 kxKGSi"><div class="sc-hlm4rl-1 iodvHu"></div><img alt="logo publisher" class="sc-hlm4rl-2 djpVeL" data-qa="POSTING_CARD_PUBLISHER" loading="lazy" src="https://imgar.zonapropcdn.com/empresas/1/00/17/40/81/43/130x70/logo_newland_1590766474077.jpg"/></div></div></span></div></div><div class="sc-i1odl-2 gMrXuN"><div class="sc-ryls1p-4 jalEBE">Exclusive</div><div class="sc-i1odl-3 kHALbX" style="justify-content:start;padding:0px;overflow:unset"><h2 class="sc-i1odl-5 kodFeO" style="display:block"><a class="sc-i1odl-30 cVmiMy" href="/propiedades/emprendimiento/ememvein-canvas-barracas-45007144.html">Canvas Barracas</a></h2><div class="sc-i1odl-6 eirRkt" style="margin:8px 0"><h5 class="sc-i1odl-11 jTsLEC"><a class="sc-i1odl-12 EWzaP" data-qa="POSTING_CARD_LOCATION" href="/propiedades/emprendimiento/ememvein-canvas-barracas-45007144.html" style="font-size:14px">Suarez 1741 Barracas, Capital Federal</a></h5></div><div class="sc-i1odl-6 kgNoEe" style="margin:2px 0px 0px;white-space:normal"><div class="sc-i1odl-31 gVYSUG"><div class="price-container"><div class="label">Desde</div><div class="price" data-qa="POSTING_CARD_PRICE_FROM">USD 83.500</div></div><div class="price-container"><div class="label">Hasta</div><div class="price" data-qa="POSTING_CARD_PRICE_TO">USD 456.200</div></div></div></div><div class="sc-i1odl-7 bJBsWF"></div><div class="sc-i1odl-6 eirRkt" style="margin:8px 0;max-height:22px"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 dqGghR" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->64 un.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 a 4 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->36 a 124 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 gVoQmK" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->43 a 164 m²<!-- --> </span></span></div></div><div class="sc-i1odl-6 eirRkt" style="align-content:start;flex-direction:row;flex-wrap:wrap;margin:8px 0;overflow:hidden"><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Gimnasio</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Parrilla</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Pileta</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Solarium</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Balcón</span><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Terraza</span></div></div><div class="sc-i1odl-6 eirRkt"></div><div c ...
# Clase no funciona
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="52334212" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-venta-villa-lugano-departamento-3-ambientes-52334212.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 109.500</div></div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">CASTAÑARES 5800. Entre Leguizamon, martiniano y Murguiondo</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Villa Lugano, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->68 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->61 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->3 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 baños<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-venta-villa-lugano-departamento-3-ambientes-52334212.html">Venta - Villa Lugano - Departamento 3 Ambientes</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Xintel(clc-clc-53) Departamento 3 ambientes a estrenar, ubicado en la Av. Castañares 5800 esquina Martiniano Leguizamón. Excelente propiedad en edificio a estrenar, pisos de porcelanato, dormitorios con placard, cocina con bajo mesada y alacenas, mesadas graníticasy griferíade primera calidad. Cocina a gas, agua caliente central por termotanques de alta recuperación, baños con artefactos de primera linea con accesorios incluidos. Preinstalaciones de aire acondicionado y un equipo por unidad instalado en el ambiente principal. Todas las unidades cuentan con vista abierta y balcón al frente. Hall de entrada: pisos de porcelanato, paredes espejadas y portero visor. Cocheras: portón automático con control remoto. Bauleras. Aberturas de aluminio anordizado y vidrios dvh. Sum, solarium. Zona residencial a 300 metros de la Plaza Granada y centro comercial. Excelente conectividad a los accesos de la autopista Dellepiane, Ricchieri y avenida General Paz. A 500 metros de la estaciónde tren Lugano del Belgrano Sur, conectando al barrio con la EstaciónBs. As. Proximidad a distintas paradas de colectivos que conectan al barrio con resto de la Ciudad y Gran Buenos Aires. -- consultanos por financiación privada sin requisitos -- -- Las superficies y medidas aquí informadas son aproximadas y a solo efecto orientativo --</div></div><div><span class="sc-ryls1p-0 bzIPYI" color="#7C98A7" label="Super destacado">Super destacado</span></div></div><div class="sc-i1odl-4 kkjIdG"><div class="sc-hlm4rl-3 jyNRdv"><div class="sc-hlm4rl-0 iatNmF"><div class="sc-hlm4rl-1 iodvHu"></div><img alt="logo publishe ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="52322496" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-venta-depto-2-amb-villa-urquiza-cochera-amenities-52322496.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 145.000</div></div><div class="sc-12dh9kl-2 kzrlNE" data-qa="expensas">$ 80.000 Expensas</div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Echeverria 4200</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Villa Urquiza, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->56 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->48 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 baño<!-- --> </span></span><span><img class="sc-1uhtbxc-1 eykaou" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 coch.<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-venta-depto-2-amb-villa-urquiza-cochera-amenities-52322496.html">Venta Depto 2 Amb Villa Urquiza Cochera Amenities</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Corredor Responsable: Ariel Champanier cucicba 4330 / Andrea Berré cmcpsi 6763- Contacto: Laura Viglierchio - mls id # Ver datos-54. Departamento de 2 ambientes en venta con balcón, edificio full amenities en la mejor zona de Villa Urquiza. Cochera fija y baulera, ingreso por portón automático. Seguridad 24 hs. Distribución: Living comedor con salida al balcón. Cocina integrada con barra desayunadora y muy buen espacio de guardado. Dormitorio en suite. Baño completo. Toilette. En exclusiva zona residencial, que combina paisaje urbano con zonas verdes y arboladas, arquitectura de calidad con modernidad. Ubicado sobre Echeverría entre Holmberg y Donado. Exclusiva zona residencial. Cercano a polo gastronómico DoHo Villa Urquiza. Full amenities: Piscina con increíble vista abierta, Solarium. Gym. Laundry. Zona de juegos. sum. Parrillas. Seguridad 24 hs. Tiene contrato de alquiler vigente hasta agosto 2024. Remax Argentina S. R. L. No ejerce el corretaje inmobiliario. El presente sitio web es una plataforma en donde cada oficina inmobiliaria independiente que contrata los servicios re/max puede publicar las propiedades a su cargo. Cada oficina es de propiedad y gestión independiente, por lo que Remax Argentina S. R. L no interviene en los datos de la publicación, en la operación inmobiliaria, ni en la confección y/o firma del boleto de compraventa y/o escritura y/o contra ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="53012052" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-departamento-en-venta-4-ambientes-y-cochera-en-palermo-53012052.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 479.999</div></div><div class="sc-12dh9kl-2 kzrlNE" data-qa="expensas">$ 50.000 Expensas</div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Avenida Libertador al 5100</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Palermo, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->220 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->190 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->5 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->3 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->3 baños<!-- --> </span></span><span><img class="sc-1uhtbxc-1 eykaou" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 coch.<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-departamento-en-venta-4-ambientes-y-cochera-en-palermo-53012052.html">Departamento en Venta 4 Ambientes y Cochera en Palermo Oportunidad Libertador</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Atención real Y única oportunidad! Palermo retasado! nuevo valor totalmente rebajado! para exigentes semipiso en venta de 4 ambientes con dependencia de servicio, cochera Y baulera, se trata de un departamento en la mejor ubicación sobre la avenida del libertador A pasos de los mejores lugares de buenos aires del hipódromo de palermo, de la universidad de belgrano, del lawn tenis de palermo, de los bosques de palermo Y de los mejores lugares gastronómicos, realmente es un semipiso que tiene su entrada principal Y un inmenso Y gran living Y comedor, con gran vista, Y un balcón aterrazado para disfrutar la avenida libertador, tiene un toilette de recepción, tiene 3 dormitorios, uno de ellos es en suite con vestidor Y su gran baño, los otros dormitorios tienen su placards completos Y un baño completo aparte, en todos los ambientes tienen aire acondicionado, la calefacción es por losa radiante, tiene doble circulación, tiene un escritorio O 4° dormitorio, tiene una súper cocina completa, lavadero, dependencia Y baño de servicio Y entrada de servicio, seguridad las 24 horas, realmente es un chiche Y para gente exigente Y entendida, no se lo pierda! Para más información, llámanos al: Ver datos. Aviso publicado por khabbaz propiedades desde Sumaprop. </div></div><div><span class="sc-ryls1p-0 bzIPYI" color="#7C98A7" label="Super  ...
# ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="52051781" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-venta-duplex-3-ambientes-con-cochera-y-baulera-a-52051781.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"><span class="sc-14rw2v7-1 hVTDoz"><img class="sc-14rw2v7-2 fwUYlt" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/tagsSprite.png"/></span></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 230.000</div></div><div class="sc-12dh9kl-2 kzrlNE" data-qa="expensas">$ 35.000 Expensas</div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Ugarte al 2000</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Belgrano, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->83 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->80 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->3 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 ljuqxM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 dorm.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->2 baños<!-- --> </span></span><span><img class="sc-1uhtbxc-1 eykaou" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 coch.<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-venta-duplex-3-ambientes-con-cochera-y-baulera-a-52051781.html">Venta Dúplex 3 Ambientes con Cochera y Baulera a Estrenar en Belgrano</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Departamento de tres ambientes a estrenar en edificio de categoría, en una de las mejores ubicaciones del barrio de Belgrano. La unidad se desarrolla con living comedor, un dormitorio con baño en suite, más otro dormitorio y otro baño completo, cocina independiente y balcón, con una superficie cubierta de 80 m2 y3 m2 semicubiertos de balcón. Incluye cochera fija y baulera doble, incluido en el precio de publicación. apto profesionaldimensiones: Living Room. 6. 95 x 3. 65 mCocina/Comedor. 2. 83 x 2. 80 m Balcón. 3. 40 x 1. 10 mToilette. 1. 50 x 1. 20 mDormitorio Ppal. 3. 60 x 3. 05 mBaño en Suite. 2. 00 x 2. 00 mDormitorio. 3. 00 x 2. 80 mBaño. 2. 00 x 2. 00 mSu ubicación es estratégica ya que se encuentra en un zona residencial, una de las zonas más tranquilas y seguras del barrio, pero a su vez cosmopolita y de gran accesibilidad, a sólo 4 cuadras de la cabecera del Subte D (Estación Congreso de Tucumán) . A 3 cuadras de la avenida Cabildo (con el Metrobus y su extensa red de transporte de colectivos: 29, 41, 57, 59, 60, 68, 107, 114, 133, 152, 161, 168, 175, 184, 194) , a 5 cuadras de avenida del Libertador y a 6 cuadras de Barrancas de Belgrano y el Barrio Chino. Características del edificio: - Imp ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 crUUno" data-id="52973905" data-posting-type="PROPERTY" data-qa="posting PROPERTY" data-to-posting="/propiedades/clasificado/veclapin-departamento-monoambientes-venta-saavedra-52973905.html"><div class="sc-i1odl-1 clDfxH"><div class="sc-n2cjqs-0 kMJtwo" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><div class="sc-14rw2v7-0 kanhJG"><span class="sc-14rw2v7-1 hVTDoz"><img class="sc-14rw2v7-2 dVQpDM" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/tagsSprite.png"/></span></div></div><div class="sc-i1odl-2 ehhPMv"><div class="sc-i1odl-3 kHALbX"><div><div class="sc-i1odl-6 eirRkt"><div class="sc-i1odl-9 fUphNJ"><div class="sc-12dh9kl-0 ekRiEG"><div class="sc-12dh9kl-3 euxWti"><div class="sc-12dh9kl-4 hbUMaO" data-qa="POSTING_CARD_PRICE">USD 68.000</div></div></div><div class="sc-ryls1p-3 hrtitV"></div></div><div class="sc-i1odl-7 kmNRoT"></div><div class="sc-ge2uzh-1 gFoERJ"><div class="sc-ge2uzh-0 eXwAuU">Vedia 4700 1 D</div><div class="sc-ge2uzh-2 jneaYd" data-qa="POSTING_CARD_LOCATION">Saavedra, Capital Federal</div></div></div><div class="sc-i1odl-6 fpYkRN"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 eLhfrW" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->33 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->31 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 foetjI" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 baño<!-- --> </span></span></div></div><h2 class="sc-i1odl-11 kvKUxE"><a class="sc-i1odl-12 EWzaP" href="/propiedades/clasificado/veclapin-departamento-monoambientes-venta-saavedra-52973905.html">Departamento Monoambientes Venta - Saavedra</a></h2><div class="sc-i1odl-13 gxstUR" data-qa="POSTING_CARD_DESCRIPTION">Valores de preventa!! Edificio entre medianeras en exclusiva zona residencial de Saavedra, próximo a Parque Sarmiento y Av. Gral. Paz. Posee una fachada de ladrillo a la vista con aberturas negras de piso a techo generando calidez y luminosidad. Espectacular monoambiente al contrafrente. Contará con un hermoso balcón, amplio ambiente con placard, cocina integrada con artefactos y muebles bajo mesada/alacena de primera categoría y baño completo. Tendrá ventanas de dvh, porcelanato en ambientes principales, preinstalación de aire acondicionado, horno y anafe eléctrico. El edificio se encuentra desarrollado en pb y 4 pisos, con unidades de 1, 2 y 3 ambientes para darte mas flexibilidad a la hora de elegir tu próximo hogar. Todas las unidades cuentan con espacios al aire libre, ya sea jardín o balcón, ideal para descansar después de un día de trabajo o juntarse con amigos. Aprovecha esta oportunidad! Contactate con nosotros y te asesoramos respecto a todas las posibilidades de inversión que tenemos para ofrecerte. "Se deja constancia que los m2 y la antigüedad son aproximados, al igual que las medidas parciales y el valor consignado de las expensas mensuales (en caso que corresponda pago de expensas) están sujetos a verificación y/o ajustes, el precio del inmueble puede ser modificado sin previo aviso. En el caso de tratarse de un inmueble en construcción los detalles de terminación y la fecha de entrega están sujetos a revisión. Fotos de carácter no contractual. Las unidades publicadas están sujetas a disponibilidad. Dic propiedades S. A. Actúa solamente en carácter de comercializadora de los inmuebles ofrecidos. En caso de tratarse de un terreno, la i ...
# <div class="sc-1tt2vbg-4 dFNvko"><div class="sc-i1odl-0 kWwuJH" data-id="49981704" data-posting-type="DEVELOPMENT" data-qa="posting DEVELOPMENT" data-to-posting="/propiedades/emprendimiento/ememvein-urban-nature-paseo-colon-1062-san-telmo-capital-49981704.html"><div class="sc-i1odl-1 krobxD"><div class="sc-i1odl-32 eyOlpw"><div class="sc-n2cjqs-0 harMYs" data-qa="POSTING_CARD_GALLERY"><div class="lazyload-wrapper" style="width:100%;height:100%;position:absolute"><div class="lazyload-placeholder"></div></div><span class="sc-1j3twev-0 eIDtiR"></span><span class="sc-1j3twev-0 hnXuJe"><span class="sc-ryls1p-0 sc-bwrqy4-0 gTPIFa hZUqIS">En Construcción</span></span><span class="sc-1j3twev-0 eIDtiR"></span><span class="sc-1j3twev-0 gqVVqp"><div class="sc-hlm4rl-3 jyNRdv"><div class="sc-hlm4rl-0 kxKGSi"><div class="sc-hlm4rl-1 iodvHu"></div><img alt="logo publisher" class="sc-hlm4rl-2 djpVeL" data-qa="POSTING_CARD_PUBLISHER" loading="lazy" src="https://imgar.zonapropcdn.com/empresas/1/00/30/49/66/34/130x70/logo_equipo-6c-real-estate_1658338288367.jpg"/></div></div></span></div></div><div class="sc-i1odl-2 gMrXuN"><div class="sc-ryls1p-4 jalEBE">Exclusive</div><div class="sc-i1odl-3 kHALbX" style="justify-content:start;padding:0px;overflow:unset"><h2 class="sc-i1odl-5 kodFeO" style="display:block"><a class="sc-i1odl-30 cVmiMy" href="/propiedades/emprendimiento/ememvein-urban-nature-paseo-colon-1062-san-telmo-capital-49981704.html">Urban Nature Paseo Colón 1062 - San Telmo - Capital Federal</a></h2><div class="sc-i1odl-6 eirRkt" style="margin:8px 0"><h5 class="sc-i1odl-11 jTsLEC"><a class="sc-i1odl-12 EWzaP" data-qa="POSTING_CARD_LOCATION" href="/propiedades/emprendimiento/ememvein-urban-nature-paseo-colon-1062-san-telmo-capital-49981704.html" style="font-size:14px">Avenida Paseo Colón al 1000 San Telmo, Capital Federal</a></h5></div><div class="sc-i1odl-6 kgNoEe" style="margin:2px 0px 0px;white-space:normal"><div class="sc-i1odl-31 gVYSUG"><div class="price-container"><div class="label">Desde</div><div class="price" data-qa="POSTING_CARD_PRICE_FROM">USD 51.000</div></div><div class="price-container"><div class="label">Hasta</div><div class="price" data-qa="POSTING_CARD_PRICE_TO">USD 93.000</div></div></div></div><div class="sc-i1odl-7 bJBsWF"></div><div class="sc-i1odl-6 eirRkt" style="margin:8px 0;max-height:22px"><div class="sc-1uhtbxc-0 hpNmeK" data-qa="POSTING_CARD_FEATURES"><span><img class="sc-1uhtbxc-1 dqGghR" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->14 un.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 jkEBRn" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->1 amb.<!-- --> </span></span><span><img class="sc-1uhtbxc-1 dRoEma" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->24 a 32 m²<!-- --> </span></span><span><img class="sc-1uhtbxc-1 gVoQmK" src="https://img10.naventcdn.com/listado/RPLISv8.78.1-RC1/images/featuresSprite.png"/><span> <!-- -->24 a 47 m²<!-- --> </span></span></div></div><div class="sc-i1odl-6 eirRkt" style="align-content:start;flex-direction:row;flex-wrap:wrap;margin:8px 0;overflow:hidden"><span class="sc-ryls1p-0 kbnnji" color="#3A0C3D" style="text-transform:capitalize;margin:0 12px 8px 0;background-color:transparent">Solarium</span></div></div><div class="sc-i1odl-6 eirRkt"></div><div class="sc-i1odl-7 bJBsWF" style="width:100%"></div><div class="sc-i1odl-4 kkjIdG" style="border:none"><div class="sc-hlm4rl-3 jyNRdv"></div><div class="sc-i1odl-8 jTSHuu"><div class="sc-pr9m2p-1 fajRf"><div class="sc-pr9m2p-2 idaYLz"><button aria-label="Favorito" class="sc-1b3blmr-0 blZEzl" data-qa="CARD_FAV" font-size="16px" font-weight="500"><svg color="currentColor" fill="currentColor" font-size="25px" height="1em" stroke="currentColor" stroke-width="0" viewbox="0 0 16 14" width="1em" xmlns="http://www.w3.org/2000/svg"><path d="M8 13.7c-.1 0-.3 0-.4-.1l-5.8- ...
# Clase no funciona

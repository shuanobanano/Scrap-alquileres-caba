# %%
from config.config_jupyter import set_wd
set_wd()
import src.zonaprop as zo
from botasaurus import *
# Out:
# c:\Users\marti\OneDrive\Documentos\Trabajos Indec\Scrap alquileres caba

# %%
url_list = zo._get_url_list(2, "departamentos", "alquiler")
link = url_list[0]

# %%
request = AntiDetectRequests()

# %%
properties = []
soup = request.bs4(link)
properties += zo._parse_property_listings(soup)

# %%
posting_container = soup.find(class_='postings-container')
classes_inside_posting_container = []
for child in posting_container.children:
    if child.name and child.get('class'):
        classes_inside_posting_container.extend(child['class'])

# %%
classes_inside_posting_container
# Out:
# ['sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo',
#  'sc-1tt2vbg-5',
#  'GcsXo']

# %%
properties
# Out:
# [{'Price': '$ 450.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 46.000 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-san-nicolas-2-amb-amoblado.-impecable-53175868.html'},
#  {'Price': 'USD 1.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 118.236 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-callao-y-pacheco-de-melo-53159186.html'},
#  {'Price': 'USD 500',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': nan,
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-departamento-en-alquiler-temporario-53170740.html'},
#  {'Price': '$ 250.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 52.700 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-alquiler-monoambiente-junin-654-piso-6-luminoso-53218531.html'},
#  {'Price': '$ 380.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': nan,
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-departamento-alquiler-belgrano-2-ambientes-con-53154983.html'},
#  {'Price': 'USD 550',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 94.000 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-departamento-2-ambientes-en-alquiler-en-barrio-norte-53056606.html'},
#  {'Price': 'USD 400',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 60.000 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-departamento-mono-ambiente-o-2-ambientes-s-dividir-52876926.html'},
#  {'Price': 'USD 1.500',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 97.000 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-excelente-departamento-en-recoleta-52922712.html'},
#  {'Price': 'USD 4.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 800.000 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-alquiler-dpto.-piso-5-amb-3-coch-vista-a-barrancas-53211022.html'},
#  {'Price': 'USD 2.200',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 400.000 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-espectacular-3-amb-con-dos-suite-vista-al-polo-las-53079784.html'},
#  {'Price': 'USD 2.500',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 151.428 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-bustamente-y-pena-52410156.html'},
#  {'Price': 'USD 1.200',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': nan,
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-departamento-4-ambientes-expensas-incluidas-torre-53057791.html'},
#  {'Price': 'USD 1.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': nan,
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-alquiler-departamento-4-ambientes-amoblado-con-cochera-53233031.html'},
#  {'Price': '$ 800.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 95.200 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-alquiler-2-ambientes-en-belgrano-53183506.html'},
#  {'Price': 'USD 1.100',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': nan,
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-monoambiente-en-alquiler-temporario-a-estrenar-en-53102161.html'},
#  {'Price': '$ 500.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 52.610 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-oppel-departamento-en-alquiler-palermo-capital-41973317.html'},
#  {'Price': '$ 620.000',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 37.000 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-departamento-belgrano-52898048.html'},
#  {'Price': 'USD 3.200',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 1 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-madero-center-3-ambientes-175-m-sup2-53223901.html'},
#  {'Price': 'USD 3.500',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 10 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-alquiler-con-muebles-piso-muy-alto-torres-de-retiro-52879217.html'},
#  {'Price': 'USD 3.200',
#   'Location': nan,
#   'Address': nan,
#   'Has_photo': False,
#   'Features': [],
#   'Summarize': nan,
#   'Description': nan,
#   'Expensas': '$ 250.000 Expensas',
#   'Link': 'https://www.zonaprop.com.ar//propiedades/clasificado/alclapin-amplio-departamento-en-el-faro-2-cocheras-50928115.html'}]

# %%
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import numpy as np
import cloudscraper
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium_stealth import stealth
from selenium.webdriver.chrome.service import Service
import os
import time

from src import zona_prop_url

# %%
options = Options()
options.add_argument("--headless") # Ensures GUI is off
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

class Scraper:
    def __init__(self):
        self.driver = None

    def inicio_driver(self, link: str):
        if self.driver is None:
            service = Service(ChromeDriverManager().install())
            carpeta_descarga = os.getcwd() + "/data"
            prefs = {
                'download.default_directory': carpeta_descarga,
                "directory_upgrade": True
            }
            chrome_options = webdriver.ChromeOptions()
            chrome_options.add_experimental_option("prefs", prefs)
            self.driver = webdriver.Chrome(service=service, options=chrome_options)
            stealth(self.driver,
                    languages=["en-US", "en"],
                    vendor="Google Inc.",
                    platform="Win32",
                    webgl_vendor="Intel Inc.",
                    renderer="Intel Iris OpenGL Engine",
                    fix_hairline=True,
                    )
            self.driver.maximize_window()
        self.driver.get(link)
        return self.driver

scraper = Scraper()
driver = scraper.inicio_driver(zona_prop_url)

# Initialize the lists to store the data
prices = []
locations = []
addresses = []
features = []
descriptions = []
expensas = []

# Start scraping from the first page
while True:
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # Select all the div elements with the required class
    property_elements = soup.select('div.sc-1tt2vbg-4.dFNvko')

    # Iterate over each property element
    for property_element in property_elements:
        # Find the child elements with the required data-qa attributes
        price_element = property_element.select_one('div[data-qa="POSTING_CARD_PRICE"]')
        location_element = property_element.select_one('div[data-qa="POSTING_CARD_LOCATION"]')
        address_element = property_element.select_one('div[class="sc-ge2uzh-0 eXwAuU"]')
        features_elements = property_element.select('div[data-qa="POSTING_CARD_FEATURES"] span')
        description_element = property_element.select_one('div[data-qa="POSTING_CARD_DESCRIPTION"]')
        expensas_element = property_element.select_one('div[data-qa="expensas"]')

        # Extract the text from the elements and append it to the lists
        prices.append(price_element.text if price_element else np.nan)
        locations.append(location_element.text if location_element else np.nan)
        addresses.append(address_element.text if address_element else np.nan)
        features.append([feature_element.text for feature_element in features_elements])
        descriptions.append(description_element.text if description_element else np.nan)
        expensas.append(expensas_element.text if expensas_element else np.nan)

    # Check if there is a next page
    next_page = soup.select_one('a[data-qa="PAGING_NEXT"]')
    if next_page and next_page['href']:
        # Prepend the base URL to the href
        full_url = zona_prop_url + next_page['href']
        # Go to the next page
        driver.get(full_url)
    else:
        # No more pages, break the loop
        break

# Create a DataFrame from the lists
df = pd.DataFrame({
    'Price': prices,
    'Location': locations,
    'Address': addresses,
    'Features': features,
    'Description': descriptions,
    'Expensas': expensas
})

df
# Out:
#           Price                               Location  \
# 0   $ 1.100.000                   Belgrano C, Belgrano
# 1     $ 687.500  Centro / Microcentro, Capital Federal
# 2     USD 5.100          Barrio Norte, Capital Federal
# 3         $ 100              Belgrano, Capital Federal
# 4   $ 1.200.000              Recoleta, Capital Federal
# 5     $ 700.000              Barracas, Capital Federal
# 6     USD 5.000      Parque Patricios, Capital Federal
# 7     $ 833.340                  Palermo Soho, Palermo
# 8     USD 1.500              Recoleta, Capital Federal
# 9     USD 1.400         Puerto Madero, Capital Federal
# 10      USD 650                Retiro, Capital Federal
# 11    $ 330.000                 Boedo, Capital Federal
# 12    $ 900.000              Belgrano, Capital Federal
# 13     $ 60.000            Tribunales, Capital Federal
# 14    USD 2.800                Retiro, Capital Federal
# 15    $ 430.000               Palermo, Capital Federal
# 16    USD 6.600             Catalinas, Capital Federal
# 17    USD 3.200                Retiro, Capital Federal
# 18    USD 1.200  Centro / Microcentro, Capital Federal
# 19   USD 26.475  Centro / Microcentro, Capital Federal
#
#                                               Address  \
# 0                                  Libertador al 6200
# 1                                        Maipu al 700
# 2                               Av. Las Heras al 3300
# 3                               3 de Febrero  al 2100
# 4   Departamento en Alquiler en Recoleta Furnished...
# 5                            Av Montes de oca  al 800
# 6                                  Av. Colonia al 100
# 7                                         Oro al 2100
# 8                                     Av. Alvear 1800
# 9                                    Venezuela al 100
# 10                                     San Martín 900
# 11  Avenida independencia 3800. Entre Castro y Cas...
# 12                                      Moldes al 600
# 13                                         Parana 666
# 14                                    Florida al 1000
# 15                                    Olleros al 1600
# 16                                       Paraguay 733
# 17                                  Esmeralda al 1300
# 18                                     25 de mayo 565
# 19                                    Tucumán 1, Caba
#
#                                              Features  \
# 0   [ 75 m² ,  75 m² ,  70 m² ,  70 m² ,  1 baño ,...
# 1   [ 491 m² ,  491 m² ,  491 m² ,  491 m² ,  3 ba...
# 2   [ 250 m² ,  250 m² ,  250 m² ,  250 m² ,  1 am...
# 3   [ 150 m² ,  150 m² ,  554 m² ,  554 m² ,  7 ba...
# 4   [ 45 m² ,  45 m² ,  45 m² ,  45 m² ,  1 dorm. ...
# 5   [ 370 m² ,  370 m² ,  370 m² ,  370 m² ,  2 ba...
# 6   [ 500 m² ,  500 m² ,  400 m² ,  400 m² ,  4 ba...
# 7   [ 114 m² ,  114 m² ,  114 m² ,  114 m² ,  1 am...
# 8   [ 120 m² ,  120 m² ,  120 m² ,  120 m² ,  4 am...
# 9   [ 200 m² ,  200 m² ,  1 amb. ,  1 amb. ,  2 ba...
# 10  [ 58 m² ,  58 m² ,  58 m² ,  58 m² ,  2 amb. ,...
# 11  [ 38 m² ,  38 m² ,  35 m² ,  35 m² ,  1 amb. ,...
# 12  [ 63 m² ,  63 m² ,  55 m² ,  55 m² ,  3 amb. ,...
# 13  [ 45 m² ,  45 m² ,  45 m² ,  45 m² ,  2 baños ...
# 14  [ 180 m² ,  180 m² ,  180 m² ,  180 m² ,  4 am...
# 15  [ 45 m² ,  45 m² ,  38 m² ,  38 m² ,  2 amb. ,...
# 16  [ 550 m² ,  550 m² ,  550 m² ,  550 m² ,  2 co...
# 17  [ 320 m² ,  320 m² ,  320 m² ,  320 m² ,  4 ba...
# 18           [ 330 m² ,  330 m² ,  330 m² ,  330 m² ]
# 19  [ 1059 m² ,  1059 m² ,  1059 m² ,  1059 m² ,  ...
#
#                                           Description            Expensas
# 0   Hermosa oficina con muy buena luz natural por ...   $ 80.000 Expensas
# 1   Edificio de ss, pb y 10 pisos. Ubicado sobre l...  $ 271.952 Expensas
# 2   Presentamos Edificio " oficinas las heras ". E...   $ 50.000 Expensas
# 3   Alquiler de inigualables consultorios en 4 Pla...                 NaN
# 4   Deco recoletafurnished by Armani CasaPiscina d...                 NaN
# 5   Casona antigua con multiples ambientes. Ingres...                 NaN
# 6   Edificio de Oficinas entre medianeras de pb y ...                 NaN
# 7   ** El precio corresponde a tipología 07 (114 m...   $ 39.000 Expensas
# 8   Superficie: 120 m2. Con muebles. Departamento ...  $ 120.000 Expensas
# 9   Excelente oficina en edificio corporativo de c...   $ 96.600 Expensas
# 10  Corredor Responsable: mudate hoy S. A. - Ignac...                 NaN
# 11  Xintel(ccb-ccb-101) Alquiler de Departamento 1...   $ 29.300 Expensas
# 12  Divino 3 ambientes a Estrenar frente al nuevo ...   $ 40.000 Expensas
# 13  11 Ver datos fratelli grupo inmobiliarioalquil...   $ 72.000 Expensas
# 14  Emblematico edificio kavanagh - piso alto - ma...  $ 135.000 Expensas
# 15  Alquiler tradicional amoblado. "Este departame...   $ 25.000 Expensas
# 16  La zona denominada Plaza San Martin, es uno de...                 NaN
# 17  Edificio racionalista con excelente ubicación....  $ 220.000 Expensas
# 18  Fachada aventanada. Vigilancia 24 horas y cont...                 NaN
# 19  El Edificio República ha sido diseñado por el ...                 NaN
